# %% [markdown]
# #### Get date and time to name save files

# %%
# Measure start time
import time
from datetime import date, datetime
time_start = time.strftime("%H:%M:%S", time.localtime())
today = date.today()
now = datetime.now()
DATETIME = today.strftime("%Y%m%d")+'_'+now.strftime("%H%M%S")

# %% [markdown]
# ### User inputs

# %% [markdown]
# #### 0 - Name experiment

# %%
# Define experiment name
experiment_name = 'medBIT_r3_ft_QA'

# %% [markdown]
# #### 1 - Load answers from file?

# %%
# To save time, give the possibility to load pregenerated answers
load_pregenerated_answers = False

# If load_pregenerated_answers is True, specify subfolder and file with pregenerated answers
# If load_pregenerated_answers is False, you can ignore this parameter
pregenerated_answer = ''

save_folder = './Results/'
if not load_pregenerated_answers:
    # Create save folder
    from pathlib import Path
    Path(f'{save_folder}{DATETIME}').mkdir(parents=True, exist_ok=True)

# %% [markdown]
# #### 2 - Insert path of annotations, in Haystack format

# %%
# Insert path of file with answers, Haystack format
my_path = './Annotations/HBD_discharge_letters_docs/' # Change accordingly to your PC paths

# %% [markdown]
# #### 3 - Insert model name/path

# %%
# Models from HuggingFace
# model_checkpoint = 'luigisaetta/squad_it_xxl_cased_hub1'
# model_checkpoint = 'mrm8488/bert-italian-finedtuned-squadv1-it-alfa'
# model_checkpoint = 'deepset/xlm-roberta-large-squad2'
model_checkpoint = '../BioBIT_r3_SQuAD_BioASQ_3407/'

# Custom models
# model_checkpoint = '/home/claudio/Downloads/medBIT-r3-plus_ft_QA/'

# %% [markdown]
# #### 4 - Apply HF Pipeline OR Topic Detection?

# %%
modalities = {
    1: "PIPELINE",
    2: "TOPIC_DETECTION"
}

choice = 1
mode = modalities[choice]

# Models for Topic Detection
if mode=='PIPELINE':
    topic_model_checkpoint = ''
elif mode=='TOPIC_DETECTION':
    topic_model_checkpoint = 'MoritzLaurer/mDeBERTa-v3-base-xnli-multilingual-nli-2mil7'

# %% [markdown]
# #### 5 - Define candidate labels

# %%
# Define candidate labels for topics as questions
# candidate_labels = [t[1] for t in my_questions]

# Append some default topics
# candidate_labels.append('Dati sociodemografici')
# candidate_labels.append('Varie')

# Custom candidate labels
candidate_labels = [
    'Condizione patologica',
    'Farmaci',
    'Procedure chirurgiche',
    'Dati sociodemografici',
    'Varie'
]

# %% [markdown]
# ### Setup notebook

# %%
# Utility libraries
from itertools import repeat
import json
import numpy as np
import pandas as pd

import pdfplumber
import os
from requests import get
import string
import tqdm

# Graphic libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# NLP libraries
import torch
import transformers
from spacy.lang.it import Italian 

# Custom libraries
import my_utility as utility

# %% [markdown]
# ### Load annotations

# %%
all_annotations = utility.get_annotations_file(my_path, sort=True)

# %% [markdown]
# ### Setup pipeline

# %%
# Get data and questions from documents
data, paragraph, my_questions = utility.get_annotations_data(all_annotations)

# %%
# Remove questions
removed_question = [2]
my_questions = utility.remove_elements(my_questions, removed_question)

# %%
# Show questions
my_questions
# Out:
# [(0, 'Qual è la condizione patologica?'),
#  (1, 'Qual è l’età?'),
#  (3, 'Quali farmaci sono prescritti alla dimissione?'),
#  (4, 'Quali sono le procedure chirurgiche applicate?')]

# %% [markdown]
# ### Get answers

# %%
if load_pregenerated_answers:
    try:
        # Load pred_answers from a previously saved file
        with open(f'{save_folder}{pregenerated_answer}', 'r') as f:
            pred_answers = json.load(f)
    except:
        print('File with pregenerated answers not found!')
else:
    # Predefine a list of empty predicted answers
    pred_answers = [[] for i in repeat(None, len(data))]
    
    # Setup QA pipeline (both modes will use it)
    QA_pipeline = utility.setup_pipeline(
        'PIPELINE', 
        model_checkpoint,
        max_ans_len=30, 
        handle_impossible_ans=True
    )
    
    for j, doc in enumerate(data):
        #################### HF PIPELINE ####################
        if mode=='PIPELINE':
            for i, q in my_questions:
                QA_input = {
                    'question': q,
                    'context': doc['context']
                }
                ans = QA_pipeline(QA_input)
                ans['answer'] = ans['answer'].strip(string.punctuation+'\n')
                pred_answers[j].append((i, ans))
        elif mode=='TOPIC_DETECTION':
            # Setup TOPIC pipeline
            topic_pipeline = utility.setup_pipeline(
                'TOPIC_DETECTION', 
                topic_model_checkpoint,
                max_ans_len=30, 
                handle_impossible_ans=True
            )
            ################## TOPIC DETECTION ##################
            # 0 - Create a dict with a key for every topic
            my_text_by_topic = {s: '' for s in candidate_labels}
            # 1 - Split text in sentences
            paragraphs = utility.split_in_sentences(doc['context'])
            # Filter out empty paragraphs
            paragraphs = [p for p in paragraphs if p!='']
            for par in paragraphs:
                # 2 - Find topic for every paragraph
                pipeline_result = topic_pipeline(par, candidate_labels, multi_label=True)
                topic = utility.get_top_topic(pipeline_result)
                # 3 - Add text to its topic
                my_text_by_topic[topic]+=f'\n{par}'
            # 4 Search answer only in specific topic
            for i, q in my_questions:
                q_topic = utility.get_top_topic(topic_pipeline(q, candidate_labels, multi_label=True))
                try: # context could be empty
                    QA_input = {
                        'question': q,
                        'context': my_text_by_topic[q_topic]
                    }
                    ans = QA_pipeline(QA_input)
                    ans['answer'] = ans['answer'].strip(string.punctuation+'\n')
                except:
                    ans = {'score': 0, 'start': 0, 'end': 0, 'answer': ''}
                pred_answers[j].append((i, ans))

# %%
# Save pred_answers to file to load it later, if not loaded
if not load_pregenerated_answers:
    with open(f'{save_folder}{DATETIME}/pred_answers_{DATETIME}.json', 'w') as f:
        json.dump(pred_answers, f, indent=4)

# %% [markdown]
# ### Show results

# %%
# Create variables
pred_ans_for_stats = [[] for i in repeat(None, len(all_annotations))] # List of predicted answers, used to calculate results
correct_ans_for_stats = [[] for i in repeat(None, len(all_annotations))] # List of reference answers, used to calculate results

# Populate list of predicted and correct answers
# They will be used to calculate statistical parameters
for k, doc in enumerate(data):
    counter = 0
    for i, q in my_questions:
        corr_ans_index = k*(len(my_questions)+1)+i
        pred_ans_for_stats[k].append(pred_answers[k][counter][1]["answer"].lower().strip(string.punctuation+' '))
        correct_ans_for_stats[k].append(doc[f"answer_{corr_ans_index}"].lower().strip(string.punctuation+' '))
        counter+=1

# %%
for i in range(len(pred_ans_for_stats)):
    print('*'*50+f' Document index {i} '+'*'*50)
    for j, (ref, pred) in enumerate(zip(correct_ans_for_stats[i], pred_ans_for_stats[i])):
        print(f'Question: "{my_questions[j][1]}"')
        print(f'Reference answer: "{ref}"')
        print(f'Predicted answer: "{pred}"')
        print('^'*30)
# Out:
# ************************************************** Document index 0 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "stenosi valvolare aortica severa"
# Predicted answer: "tvp"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "74"
# Predicted answer: "74"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp ore 8
# -  clopidogrel 75 mg 1 cp dopo pranzo
# -  bisoprololo 1.25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  ramipril 5 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  furosemide 500 mg ¼ cp alle ore 8 e ¼ alle ore 20
# -  canreonato di potassio 100 mg ½ cp alle ore 16
# -  levotiroxina 100 mcg 1 cp a digiuno alle ore 7
# -  tiotropio respimat 2 inalazioni al mattino
# -  lorazepam 1 mg 1 cp alle ore 22
# -  domperidone 1 cp a pranzo e a cena"
# Predicted answer: "bioprotesi"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione
# valvolare  aortica"
# Predicted answer: "ministernotomia"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 1 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "disfuzione di bioprotesi in esiti di svao con insufficienza severa"
# Predicted answer: "ipertensione arteriosa"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "65"
# Predicted answer: "65"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp alle ore 8
# -  acenocumarolo 4 mg sec inr alle ore 18 (inr del 31.01.21 = 2.21 dose ¼ cp, inr odierno
# =  3.31, dose 0 cp)
# -  metoprololo 100 mg ½ cp alle ore 8, ½ cp alle ore 14 e ½ cp alle ore 20
# -  ramipril 5 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  cloruro di potassio 600 mg 1 cp alle ore 12 e 1 cp alle ore 20, da sospendere secondo
# kaliemia
# -  furosemide 25 mg 2 cp alle ore 8 e 2 cp alle ore 20
# -  canreonato di potassio 100 mg ½ cp alle ore 16
# -  lorazepam 1 mg 1 cp alle ore 8
# -  quetiapina 25 mg 1 cp alle ore 22 (da sospendere eventualmente prima del rientro a domicilio"
# Predicted answer: "lasix"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione valvolare aortica"
# Predicted answer: "cardiochirurgico"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 2 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "coronaropatia critica trivasale"
# Predicted answer: "endocardite batterica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "52"
# Predicted answer: "52"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp alle ore 8
# -  acido acetilsalicilico 100 mg 1 cp dopo pranzo
# -  ticagrelor 90 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  bisoprololo 1.25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  furosemide 25 mg 2 cp alle ore 8 e 1 cp alle ore 20
# -  canreonato di potassio 100 mg ½ cp alle ore 16
# -  atorvastatina 40 mg 1 cp alle ore 22
# -  tiotropio respimat 2 inalazioni al mattino
# -  prednisone 25 mg 1 cp alle ore 8 per 5 giorni, quindi scalare"
# Predicted answer: "interferon"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "intervento di rivascolarizione miocardica"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 3 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "versamento pericardico"
# Predicted answer: "sclerodermia"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "87"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp alle ore 8
# -  valsartan 80 mg 1 cp alle ore 8
# -  furosemide 25 mg ½ cp alle ore 8
# -  prednisone 25 mg 1 cp alle ore 8"
# Predicted answer: "visite di controllo"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "pericardiocentesi percutanea"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 4 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "stenosi valvolare aortica severa in valvola bicuspide"
# Predicted answer: "endocardite batterica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "66"
# Predicted answer: "66"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp ore 8-20
# -  acenocumarolo 4 mg sec inr alle ore 16 (inr odierno =  1.16 dose 1cp )
# -  enoxaparina 6000 u sc alle ore 18 fino a raggiungimento di inr stabile e a range terapeutico
# -  bisoprololo 1.25 mg 2 cp alle ore 8 e 1cp alle ore 18
# -  zolpidem 10  1 cp alle ore 22
# -  furosemide 25 mg 2 cp alle ore 8 e 2 cp ore 18
# -  atorvastatina 10 mg 1 cp alle ore 22
# -  lexotan  3mg 1cp ore 22
# -  tiotropio respimat 2 inalazioni al mattino
# -  rolufta 55 pp 1 puff ore 8
# -  febuxostat 80 mg 1cp ore 22
# humulin r 4 ui ai pasti sec  dtx"
# Predicted answer: "amiodarone"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione valvolare aortica con protesi meccanica st jude reagent n°21"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 5 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "coronaropatia critica di iva e stenosi valvolare aortica severa"
# Predicted answer: "dimissione"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "77"
# Predicted answer: "77"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp/die ore 8
# -  acido acetilsalicilico 100 mg 1 cp/die dopo pranzo
# -  ticagrelor 90 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  bisoprololo 1.25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  ramipril 2.5 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  furosemide 20 mg 1 fl ev alle ore 8 + 1 fl ev alle ore 14 + 1 fl ev alle ore 20
# -  canreonato di potassio 25 mg 1 cp alle ore 16
# -  atorvastatina 100 mg ½ cp alle ore 22
# -  spiolto 1 inalazione al mattino e 1 inalazione la sera
# -  tamsulosina 0.4 mg 1 cp alle ore 20"
# Predicted answer: "bioprotesi"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione valvolare aortica con bioprotesi intuity n° 23 +
# rivascolarizzazione miocardica mediante bpac x 1 (lima-iva"
# Predicted answer: "profilassi antibiotica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 6 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "stenosi valvolare aortica in bicuspidia, aneurisma dell’aorta ascendente"
# Predicted answer: "cad"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "55"
# Predicted answer: "55"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp alle ore 8
# -  acenocumarolo 4 mg sec inr alle ore 18 (inr del 06.04.21 = 1.73 dose ¼ cp, inr odierno
# = 1.66 dose ½ cp da somministrare)
# -  bisoprololo 1.25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  ramipril 5 mg 1 cp alle ore 8
# -  furosemide 25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  canreonato di potassio 25 mg 1 cp alle ore 16
# -  enoxaparina 4000 u sc alle ore 18 fino al raggiungimento di inr stabile e terapeutico
# -  escitalopram 10 mg 1 cp alle ore 22"
# Predicted answer: "visite di controllo"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione valvolare aortica e sostituzione
# aorta  ascendente  con  reimpianto  delle  arterie  coronarie"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 7 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "insufficienza  valvolare  mitralica  severa"
# Predicted answer: "polmonite interstiziale"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "69"
# Predicted answer: "69"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp ore 8
# -  acenocumarolo 4 mg sec inr alle ore 16 (inr del 14.10.21 = 1.63 dose ½ cp, inr odierno
# = 2.71 dose 0 cp)
# -  bisoprololo 2.5 mg 1 cp alle ore 8
# -  ramipril 5 mg 1 cp alle ore 8
# -  furosemide 25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  canreonato di potassio 25 mg 1 cp alle ore 16
# -  tiotropio respimat 2 inalazioni al mattino"
# Predicted answer: "valvolare  mitralica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "intervento  di
# plastica valvolare mitralica con anello simulus n° 29 in minitoracotomia dx"
# Predicted answer: "colecictectomia"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 8 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "insuffcienza valvolare aortica postreumatica"
# Predicted answer: "epilessia"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "31"
# Predicted answer: "31"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp ore 8
# -  acido acetilsalicilico 100 mg 1 cp dopo pranzo
# -  bisoprololo 1.25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  ramipril 2.5 mg 1 cp alle ore 8
#
# -  furosemide 25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  canreonato di potassio 25 mg 1 cp alle ore 16
# -  carbamazepina 400 mg 1 cp alle ore 8 e 1 cp+1/2 cp alle ore 20
# -  topiramato 1 cp alle ore 8 e 1 cp alle ore 20"
# Predicted answer: "inotropi"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione valvolare aortica con bioprotesi edwards resilia 23"
# Predicted answer: "plastica/ sostituzione valvola aortica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 9 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "insufficienza valvolare mitralica severa da prolasso del lembo posteriore"
# Predicted answer: "dimissione"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "48"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 20 mg 1 cp alle ore 8
# -  acenocumarolo 4 mg sec inr alle ore 18 (inr del 22.03.21 = 1.73 dose ½ cp, inr odierno
# = 1.95 dose ¼ cp da somministrare)
# -  bisoprololo 2.5 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  ramipril 5 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  furosemide 25 mg 1 cp alle ore 8 e 1 cp alle ore 20
# -  canreonato di potassio 25 mg 1 cp alle ore 16
# -  ibuprofene 600 mg 1 cp alle ore 8 e 1 cp alle ore 20 a stomaco pieno per 5 giorni, quindi
# valutare"
# Predicted answer: "ibuprofene"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "intervento di plastica valvolare mitralica con 2 corde di
# goretex su p3 + emianello medtronic simulus 29 in minitoracotomia dx"
# Predicted answer: "riparazione /
# sostituzione valvolare"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 10 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "◦ k della mammella sinistra
#         ◦ linfoadenopatia ascellare sinistra
#         ◦ anamnesi di carcinoma indifferenziato del rinofaringe
#         ◦ esiti di poliomielite
#         ◦ ipertensione arteriosa"
# Predicted answer: "cardiopatia ipertensiva"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: "cranio"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "agobiopsia mammaria ("e' stata eseguita agobiopsia per tipizzazione istologica di lesione palpabile di circa 2 cm, altamente sospetta per eteroplasia, localizzata in sede retroareolare sinistra.")
#     8. agoaspirato linfonodale ("e' stato eseguito agoaspirato per tipizzazione citologica di linfonodo di circa 3 cm, con corticale ispessita, localizzato in ascella sinistra"
# Predicted answer: "agobiopsia mammaria"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 11 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "recidiva di poliposi rinosinusale
# "
# Predicted answer: "poliposi rinosinusale"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: "poliposi rinosinusale
#
# durante la degenza ha eseguito: intervento in anestesia generale (07/11/2019"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "comuni analgesici al bisogno, lavaggi con soluzione fisiologica 2 volte/die + rinostil plus 2 puff per narice 2 volte/die per 1 mese"
# Predicted answer: "analgesici al bisogno"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "antrostomia bilaterale e toilette dei seni mascellari + etmoidectomia anteriore"
# Predicted answer: "antrostomia bilaterale e toilette dei seni mascellari + etmoidectomia anteriore"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 12 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "piccolo aneurisma splenico ilare.calcolosi renale. ipotiroidismo"
# Predicted answer: "aneurisma splenico ilare"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 13 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "k q.i.e. mammella dx"
# Predicted answer: "dolore"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "analgesici al bisogno"
# Predicted answer: "analgesici al bisogno"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "biopsia linfonodo sentinella con esame intraoperatorio (o.s.n.a.)
#     • quadrantectomia
#     • reshaping
#     • drenaggio"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 14 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "valvulopatia aortica, aneurisma dell’aorta ascendente"
# Predicted answer: "ipertensione arteriosa"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "32"
# Predicted answer: "32"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "cardioaspirin 100 mg cp     1  cp/die (dopo pranzo)
# pariet 20 mg cp             1 cp/die (ore 8)
# eutirox 100 mcg cp                                1cp/die ( ore 8)
# coripren 20/20 cp                                   0,5cp/die ( ore 8)
# ezetrol 10 mg cp                                     1cp/die ( ore 20)
# indoxen 50 mg cp                                    1cp/die (ore 8) ( per 1 settimana"
# Predicted answer: "amoxicillina"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione valvolare aortica con protesi biologica (edwards magna perimount n°21) sostituzione dell’aorta ascendente e con protesi hemashield 30"
# Predicted answer: "sostituzione valvolare"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 15 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "cicatrici deturpanti in esito di dermolipectomia post calo ponderale"
# Predicted answer: "cicatrici deturpanti in esito di dermolipectomia post calo ponderale"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "• analgesici al bisogno
#     • elastocompressione per 3 settimane"
# Predicted answer: "analgesici"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "revisioni cicatrici e dermolipectomia"
# Predicted answer: "elastocompressione"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 16 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "dlbcl"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "cardicor cpr 1,25 mg 1 cpr die
# keppra cpr 500 mg 1 cpr al mattino e 2 cpr la sera x 10 giorni, poi keppra 1000 mg 1 cpr x 2 die
# aspirinetta cpr 1 cpr die
# cardicor  1 cp  1,25  mg   1 bust"
# Predicted answer: "keppra"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 17 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "leucemia linfatica cronica b con del(17p), b binet . ipogammaglobulineamia secondaria.
#
#
# epatopatia cronica hbv-correlata"
# Predicted answer: "b-llc"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: ""
# Predicted answer: "ig"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: "coagulazione"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 18 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "artriopatia obliterante cronica con neuropatia degli arti inferiori in paziente affettoa da insufficienza renale cronica iv stadio k-doqi portatore di nefrostomia; idronefrosi bilaterale. ipertensione arteriosa; linfedema cronico dell'arto inferiore sinistro"
# Predicted answer: "artriopatia"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "lyrica 25 mg 1 cp x 2 vv/die
# congescor 1,25 mg 1 cp/die
# triatec 2,5 mg 1 cp/die
# lasix 1 cp x 2 vv/die
# zyloric 300 mg 1/2 cp/die
# cardioaspirin 100 mg 1 cp/die
# pantorc 20 mg 1 cp/die
# impacchi quotidiani con vaselina salicilica 5% sulle lesioni ipercheratosiche dell'arto inferiore sinistro
# "
# Predicted answer: "k-doqi"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: "nefrectomia bilaterale con nefrostomie"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 19 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "febbre, epato-splenomegalia, piastrinopenia, transitoria ipertransaminasemia: mononucleosi (infezione acuta da virus di epstein-barr in fase di sieroconversione"
# Predicted answer: "uropatia ostruttiva"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: "faringodinia, con scarso beneficio con terapia antibiotica praticata a domicilio"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 20 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "enterorragia verosimilmente iatrogena ( paziente in trattamento con noac) in paziente con cardiopatia fibrillante, ipertensione arteriosa, ipertiroidismo"
# Predicted answer: "gastrite superficiale erosiva"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "olpress 20                    1/2 cp/die
# tapazole                        1 cp/die
# pantopan 40                  1 cp/die
# eliquis 5 mg               1 cp x 2/die ( si allega piano terapeutico)
# clexane 0.6                  1 fl x 2/die sc ( sospendere quando inizia eliquis)
# lasix 25                              1 cp/die"
# Predicted answer: "pradaxa"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 21 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "insufficienza cardiaca diastolica con dilatazione delle sezioni dx in fa in tao in labile compenso (scompenso congestizio= edemi degli arti inferiori cospicui)) con  ipertensione polmonare. ulcere da flebostasi degli arti inferiori infette (  pseudomonas aeruginosa ) . gonartrosi severa dx sottoposta ad artrocentesi. diabete mellito tipo 2 scompensato e complicato da nefropatia.  insufficienza renale cronica  regredita"
# Predicted answer: "artrite settica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "eucreas 50 mg/1000 mg 1 cp per 2 vv/die
#     • baypress 20 mg - 1 cp/die
#     • eliquis 2,5 1 cp per 2 vv/die
#     • carvedilolo 6,25 mg - 1 cp/die
#     • lasix 25 mg - 1 cp per 2 vv/die
#     • luvion 50 mg - 1 cp/die
#     • ciproxin 500 mg - 1 cp per 2 vv/die per 10 giorni"
# Predicted answer: "claritromicina, piperacillina/tazobactam"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "artrocentesi ( 17.0718)  del ginocchio dx con prelievo di liquido sinoviale"
# Predicted answer: "artrocentesi"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 22 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "malattia renale cronica al 4° stadio k/doqi"
# Predicted answer: "urobilinogeno"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "ensure plus: 1barattolo/die;
#     • lansox 15: 1 cp/die ore 8.00
#     • zyloric 300: 1 cp/die ore 12.00
#     • moduretic: 1/2 cp/die ore 8.00
#     • deltacortene 25 mg: 1 cp/die, ore 8.00"
# Predicted answer: "zyloric"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 23 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "processo espansivo multiplemintraparenchimali (frontale sinistra, temporo-parietale dx"
# Predicted answer: "patologia infiammatoria demielinizzante"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "keppra 500 1 cpr per 2 volte al dì;
# - soldesam 4 mg 1 fl im al dì  im per 15 giorni; successivamente deltacortene 25 mg 1 cpr per 2 volte al dì per 5 giorni ; successivamente 1 cpr al dì per ulteriori 5 giorni;
# - antra da 20 mg 1 cpr / die per 20 giorni"
# Predicted answer: "keppra"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "al momento, non indicazioni a manovre neurochirurgiche"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 24 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "esitii di pregressa legatura di varici esofagee. gastropatia congstizia. cirrosi epatica esotossica.  anemia da perdita"
# Predicted answer: "cirrosi epatica esotossica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "inderal 20 mg 1 cp
# omeprazolo 20 mg 1 cp
# gastrogel bs 1 x 2 die
# prefolic 1 cp die per 10 giorni
# vitaminici (benadon benerva"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: "legatura elastica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 25 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "febbre in soggetto con malattia renale cronica iii stadio k/doqi affetto da tetraparesi spastica  in esito ad ecefalite connatale, epilessia parziale completa, s.di gilbert"
# Predicted answer: "sideremia"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "rivotril  8 gtt x 3
# alprazolam  15 gtt x 3
# gravivipea
# clexane  4000 x 2 s.c"
# Predicted answer: "p.e.g.per nutrizione enterale"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: "p.e.g.per nutrizione enterale"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 26 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "gastroenterite e colite acuta.  infezione da citomegalovirus.  epatosplenomegalia. linfoadenopatia addominale. idrope della colecisti con calcoli. dilatazione della vbp e vbi.  malnutrizione. posizionato pic. gastrite acuta con infezione da hp. fibromiomatosi uterina. cisti annessiali"
# Predicted answer: "ipertensione arteriosa"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: "milza"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "ganciclovir (si allega piano terapeutico)
# deltacortene 25 mg. x 2 die per 1 settimana poi scalare di 5 mg a settimana"
# Predicted answer: "ganciclovir"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 27 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "valvulopatia mitralica,e valvulopatia tricuspidalica"
# Predicted answer: "chd"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: "79"
# Predicted answer: "79"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantorc 20 mg cp                                                              1cp/die ( ore 8)
# cardioasa 100 mg cp                                                       1cp/die ( ore 13)
# ramipril 2,5 mg cp                                                            1cp/die ( ore 12)
# lentokalium cp                                                                 1cp/die ( ore 8)
# seleparina o.6                                                                  1fl/die ( ore 8"
# Predicted answer: "amoxicillina"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sostituzione valvolare mitralica con protesi biologica (medtronic mosaic porcina n°29 ) ed anuloplastica tricuspidalica con anello physio n°30"
# Predicted answer: "cardochirurgico"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 28 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "peritonite da appendicite acuta"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "paracetamolo 500mg 1 cp al bisogno, max 4cp/die da assumere a distanza di 6 ore"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "laparoscopia esplorativa, appendicectomia, toilette, drenaggi"
# Predicted answer: "brecce chirurgiche"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 29 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "obesità di ii grado; infezione delle vie urinarie"
# Predicted answer: "obesità di ii grado; infezione delle vie urinarie"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "pantoprazolo 40: 1 cp al dì"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: "sleeve-gastrectomy"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 30 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "lagoftalmo od"
# Predicted answer: "lagoftalmo"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: "lagoftalmo"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "augmentin"
# Predicted answer: "augmentin"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "sospensione palpebra inferiore destra mediante fascia lata-plastica a z di cicatrice palpebra inferiore destra e sondaggio delle vie lacrimali"
# Predicted answer: "sondaggio delle vie lacrimali"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 31 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "• trauma toracico chiuso da caduta accidentale
#     • frattura arco laterale di iv-v-vi-vii costa destra
#     • falda di pnx apicale destra"
# Predicted answer: "trauma toracico chiuso"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "contramal"
# Predicted answer: "terapia analgesica"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 32 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "gozzo multinodulare pretossico, ipertrigliceridemia"
# Predicted answer: "ipertrigliceridemia"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "aumentare tapazole: mezza cpr al dì tutti i giorni"
# Predicted answer: "etg tiroide"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: ""
# Predicted answer: "fnac"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 33 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "• ernia mediana anteriore della parete addominale
#     • pregressa ernioplastica ombelicale"
# Predicted answer: "ernia mediana anteriore della parete addominale"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "analgesici"
# Predicted answer: "analgesici"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "ernioplastica della parete addominale con protesi"
# Predicted answer: "ernioplastica della parete addominale con protesi"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 34 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "stenosi carotidea sinistra serrata sintomatica complicata da emiparesi destra con esiti neuromotori da ictus cerebrale mca dx datea sinistra"
# Predicted answer: "ecd tsa"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "norvasc 5mg /die; carvedilolo 6,25mg /die; olanzapina 5mg x2/ ;die madopar 1/2 cpsx2/die"
# Predicted answer: ""
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "tea carotide sinistra (12/04/2015) tracheostomia percutanea (23/04/2018) peg (29/04/2015"
# Predicted answer: "ecd tsa"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ************************************************** Document index 35 **************************************************
# Question: "Qual è la condizione patologica?"
# Reference answer: "lesione espansiva cerebrale"
# Predicted answer: "glioma"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Qual è l’età?"
# Reference answer: ""
# Predicted answer: "veniva"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali farmaci sono prescritti alla dimissione?"
# Reference answer: "continuazione della terapia faramcologica in atto"
# Predicted answer: "rmn encefalo"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Question: "Quali sono le procedure chirurgiche applicate?"
# Reference answer: "intervento di asportazione di glioma parieto-occipitale
# destro"
# Predicted answer: "glioma parieto-occipitale
# destro"
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# ### Elaborate results

# %% [markdown]
# #### Global results

# %%
results, all_TP_global, all_FP_global, all_FN_global = utility.elaborate_results_global(
    pred_ans_for_stats, 
    correct_ans_for_stats,
    all_annotations, 
    my_questions, 
    pred_answers, 
    model_checkpoint, 
    show_answers=False
)

# %%
print(f'GLOBAL EM = {results["EM_TOTAL"]*100:.2f}%')
print(f'GLOBAL EM (NOT EMPTY ANSWERS) = {results["EM_NOT_EMPTY_TOTAL"]*100:.2f}%')
print(f'GLOBAL P = {results["P_TOTAL"]*100:.2f}%')
print(f'GLOBAL R = {results["EM_TOTAL"]*100:.2f}%')
print(f'GLOBAL F1 WEIGHTED = {results["F1_WEIGHTED_TOTAL"]*100:.2f}%')
print(f'GLOBAL F1 MACRO = {results["F1_MACRO_TOTAL"]*100:.2f}%')
# Out:
# GLOBAL EM = 31.25%
# GLOBAL EM (NOT EMPTY ANSWERS) = 13.89%
# GLOBAL P = 40.49%
# GLOBAL R = 31.25%
# GLOBAL F1 WEIGHTED = 9.11%
# GLOBAL F1 MACRO = 17.29%

# %% [markdown]
# #### By question

# %%
df_questions = utility.elaborate_results_by_question(
    all_TP_global, 
    all_FP_global, 
    all_FN_global
)

# %%
# Convert dataframe to heatmap, by questions
sns.set(font_scale=2)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_questions, cmap='RdYlGn', annot=True, fmt=".2f", annot_kws={"fontsize":20}, vmin=0, vmax=100)
fig.savefig(f'{save_folder}{DATETIME}/Questions_heat_{DATETIME}.png', dpi=400, transparent=True, bbox_inches='tight')

# %% [markdown]
# #### By document

# %%
df_documents = utility.elaborate_results_by_document(
    all_TP_global, 
    all_FP_global, 
    all_FN_global
)

# %%
# Convert dataframe to heatmap, by document
sns.set(font_scale=2)
fig, ax = plt.subplots(figsize=(10,20))
sns.heatmap(df_documents, cmap='RdYlGn', annot=True, fmt=".2f", annot_kws={"fontsize":20}, vmin=0, vmax=100)
fig.savefig(f'{save_folder}{DATETIME}/Documents_heat_{DATETIME}.png', dpi=400, transparent=True, bbox_inches='tight')

# %%
# General info
session_info = json.loads(get('https://ipinfo.io').content.decode('utf8'))
session_info['time_start'] = time_start
session_info['experiment_name'] = experiment_name
session_info['mode'] = mode
session_info['qa_checkpoint'] = model_checkpoint
if mode=='TOPIC_DETECTION':
    session_info['topic_checkpoint'] = topic_model_checkpoint
session_info['annotations'] = all_annotations
session_info['time_end'] = time.strftime("%H:%M:%S", time.localtime())

# QABot results
session_info['global_results'] = {
    'EM Score': float(f'{results["EM_TOTAL"]*100:.2f}'),
    'EM Score not empty': float(f'{results["EM_NOT_EMPTY_TOTAL"]*100:.2f}'),
    'Precision': float(f'{results["P_TOTAL"]*100:.2f}'),
    'Recall': float(f'{results["R_TOTAL"]*100:.2f}'),
    'F1-Score (weighted)': float(f'{results["F1_WEIGHTED_TOTAL"]*100:.2f}'),
    'F1-Score (macro)': float(f'{results["F1_MACRO_TOTAL"]*100:.2f}'),
}
session_info['results_by_question'] = df_questions.to_dict()
session_info['results_by_document'] = df_documents.to_dict()

with open(f'{save_folder}{DATETIME}/session_info_{DATETIME}.json', "w") as outfile:
    outfile.write(json.dumps(session_info, indent=4))

# %% [markdown]
# # TO TEST

# %% [markdown]
# ### Calculate BLEU score

# %%
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu

# %%
# BLEU score of all answers
# score = corpus_bleu(ref_corpus_bleu, pred_corpus_bleu)
# score = sentence_bleu(reference, candidate)
weights_list = [(1, 0, 0, 0), (1/2, 1/2, 0, 0), (1/3, 1/3, 1/3, 0), (1/4, 1/4, 1/4, 1/4)]
for index, (_, question) in enumerate(my_questions):
    print(f'Scores of question: {question}')
    ref_corpus_bleu = [[i[index].split()] for i in correct_ans_for_stats]
    pred_corpus_bleu = [i[index].split() for i in pred_ans_for_stats]
    score_list = corpus_bleu(ref_corpus_bleu, hypotheses=pred_corpus_bleu, weights=weights_list)
    for index, score in enumerate(score_list):
        print(f'Bleu score for {index+1}-grams:  {round(score, 2)*100}%')
# Out:
# Scores of question: Qual è la condizione patologica?
# Bleu score for 1-grams:  1.0%
# Bleu score for 2-grams:  1.0%
# Bleu score for 3-grams:  0.0%
# Bleu score for 4-grams:  0.0%
# Scores of question: Qual è l’età?
# Bleu score for 1-grams:  21.0%
# Bleu score for 2-grams:  0.0%
# Bleu score for 3-grams:  0.0%
# Bleu score for 4-grams:  0.0%
# Scores of question: Quali farmaci sono prescritti alla dimissione?
# Bleu score for 1-grams:  0.0%
# Bleu score for 2-grams:  0.0%
# Bleu score for 3-grams:  0.0%
# Bleu score for 4-grams:  0.0%
# Scores of question: Quali sono le procedure chirurgiche applicate?
# Bleu score for 1-grams:  2.0%
# Bleu score for 2-grams:  2.0%
# Bleu score for 3-grams:  2.0%
# Bleu score for 4-grams:  2.0%
# /home/claudio/.local/lib/python3.10/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/claudio/.local/lib/python3.10/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/claudio/.local/lib/python3.10/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
